# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv',header=0)

# %%
df_label = pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv',header=0)

# %%
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label['STATUS'], labels = pd.factorize(df_label['STATUS'])

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label_clean = df_label[df_label['STATUS'] != 0]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 10
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0     825151
# 10     14194
# Name: STATUS, dtype: int64

# %%
df_label_clean.groupby('ID').mean()
# Out:
#          MONTHS_BALANCE    STATUS
# ID
# 5001711       -2.000000  0.000000
# 5001712       -9.000000  0.000000
# 5001717      -10.500000  0.000000
# 5001718      -18.724138  0.689655
# 5001719      -21.000000  0.000000
# ...                 ...       ...
# 5150480      -36.500000  0.000000
# 5150482      -19.500000  0.000000
# 5150484       -6.000000  0.000000
# 5150485       -0.500000  0.000000
# 5150487      -14.500000  0.000000
#
# [41449 rows x 2 columns]

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
df_label_group
# Out:
#          MONTHS_BALANCE  STATUS
# ID
# 5001711       -2.000000     0.0
# 5001712       -9.000000     0.0
# 5001717      -10.500000     0.0
# 5001718      -18.724138     1.0
# 5001719      -21.000000     0.0
# ...                 ...     ...
# 5150480      -36.500000     0.0
# 5150482      -19.500000     0.0
# 5150484       -6.000000     0.0
# 5150485       -0.500000     0.0
# 5150487      -14.500000     0.0
#
# [41449 rows x 2 columns]

# %%
client_id = df_label_group.index.values
client_label = df_label_group['STATUS'].values

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis = 0)

# %%
df_clean.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.groupby('NAME_HOUSING_TYPE')['NAME_HOUSING_TYPE'].count()
# Out:
# NAME_HOUSING_TYPE
# Co-op apartment          1539
# House / apartment      393831
# Municipal apartment     14214
# Office apartment         3922
# Rented apartment         5974
# With parents            19077
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
df_clean_drop = df_clean.drop(['DAYS_BIRTH', 'FLAG_EMAIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_MOBIL'], axis = 1)

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
#df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
df_clean_drop = df_clean_drop.drop(['CODE_GENDER'], axis = 1)

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop['FLAG_OWN_CAR'] = pd.factorize(df_clean_drop['FLAG_OWN_CAR'])[0]
df_clean_drop['FLAG_OWN_REALTY'] = pd.factorize(df_clean_drop['FLAG_OWN_REALTY'])[0]
df_clean_drop['NAME_INCOME_TYPE'] = pd.factorize(df_clean_drop['NAME_INCOME_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean_drop['NAME_EDUCATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS'] = pd.factorize(df_clean_drop['NAME_FAMILY_STATUS'])[0]
df_clean_drop['NAME_HOUSING_TYPE'] = pd.factorize(df_clean_drop['NAME_HOUSING_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE'] = pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
X_clien_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id = np.array([item for item in X_clien_id if item in client_id])

# %%
y = np.array([client_label[client_id == item][0] for item in real_client_id])

# %%
X_final = [X[X_clien_id == item, :][0] for item in real_client_id]

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 11)

# %%
len(y)
# Out:
# 22737

# %%
sum(y==0)
# Out:
# 19648

# %%
sum(y==1)
# Out:
# 3089

# %%
3089/ (19648 + 3089)
# Out:
# 0.1358578528389849

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=1)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 4}
# 10CV accuracy : 53.40269786472318

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 52.02265372168284

# %%
import tensorflow as tf

# %%
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph() # Clear Model

    model = tf.keras.models.Sequential([
      tf.keras.layers.Dense(2500, activation='relu', input_shape=(11,)),
      tf.keras.layers.Dense(625, activation='relu'),
      tf.keras.layers.Dense(125, activation='relu'),  
      tf.keras.layers.Dense(50, activation='relu'),
      tf.keras.layers.Dense(25, activation='relu'),
      tf.keras.layers.Dense(5, activation='relu'),
      tf.keras.layers.Dense(1, activation='sigmoid')    
    ])
    return model

# %%
model = create_model()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_acc = list()
val_acc = list()
for i in range(0,200):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# 20/20 [==============================] - 1s 41ms/step - loss: 0.6930 - accuracy: 0.5072 - val_loss: 0.6955 - val_accuracy: 0.5167
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6905 - accuracy: 0.5234 - val_loss: 0.6943 - val_accuracy: 0.5207
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6897 - accuracy: 0.5323 - val_loss: 0.6935 - val_accuracy: 0.5228
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6884 - accuracy: 0.5459 - val_loss: 0.6934 - val_accuracy: 0.5308
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6873 - accuracy: 0.5512 - val_loss: 0.6927 - val_accuracy: 0.5329
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6856 - accuracy: 0.5555 - val_loss: 0.6929 - val_accuracy: 0.5369
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6834 - accuracy: 0.5619 - val_loss: 0.6942 - val_accuracy: 0.5399
# 20/20 [==============================] - 1s 35ms/step - loss: 0.
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6884 - accuracy: 0.5459 - val_loss: 0.6934 - val_accuracy: 0.5308
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6873 - accuracy: 0.5512 - val_loss: 0.6927 - val_accuracy: 0.5329
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6856 - accuracy: 0.5555 - val_loss: 0.6929 - val_accuracy: 0.5369
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6834 - accuracy: 0.5619 - val_loss: 0.6942 - val_accuracy: 0.5399
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6818 - accuracy: 0.5656 - val_loss: 0.6951 - val_accuracy: 0.5349
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6796 - accuracy: 0.5636 - val_loss: 0.6974 - val_accuracy: 0.5399
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6773 - accuracy: 0.5715 - val_loss: 0.7026 - val_accuracy: 0.5359
# 20/20 [==============================] - 1s 38ms/step - loss: 0.6759 - accuracy: 0.5753 - val_loss: 0.7027 - val_accuracy: 0.5359
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6719 - accuracy: 0.5735 - val_loss: 0.7052 - val_accuracy: 0.5147
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6681 - accuracy: 0.5844 - val_loss: 0.7056 - val_accuracy: 0.5167
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6643 - accuracy: 0.5866 - val_loss: 0.7044 - val_accuracy: 0.5369
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6625 - accuracy: 0.5851 - val_loss: 0.7041 - val_accuracy: 0.5329
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6614 - accuracy: 0.5925 - val_loss: 0.7116 - val_accuracy: 0.5258
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6609 - accuracy: 0.5851 - val_loss: 0.7134 - val_accuracy: 0.5420
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6502 - accuracy: 0.6084 - val_loss: 0.7164 - val_accuracy: 0.5389
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6450 - accuracy: 0.6175 - val_loss: 0.7178 - val_accuracy: 0.5571
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6432 - accuracy: 0.6178 - val_loss: 0.7234 - val_accuracy: 0.5379
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6437 - accuracy: 0.6170 - val_loss: 0.7182 - val_accuracy: 0.5440
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6329 - accuracy: 0.6175 - val_loss: 0.7241 - val_accuracy: 0.5470
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6226 - accuracy: 0.6248 - val_loss: 0.7344 - val_accuracy: 0.5622
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6227 - accuracy: 0.6284 - val_loss: 0.7273 - val_accuracy: 0.5672
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6223 - accuracy: 0.6327 - val_loss: 0.7379 - val_accuracy: 0.5602
# 20/20 [==============================] - 1s 37ms/step - loss: 0.6224 - accuracy: 0.6370 - val_loss: 0.7206 - val_accuracy: 0.5450
# 20/20 [==============================] - 1s 36ms/step - loss: 0.6179 - accuracy: 0.6352 - val_loss: 0.7113 - val_accuracy: 0.5581
# 20/20 [==============================] - 1s 35ms/step - loss: 0.6117 - accuracy: 0.6469 - val_loss: 0.7200 - val_accuracy: 0.5440
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5990 - accuracy: 0.6522 - val_loss: 0.7343 - val_accuracy: 0.5531
# 20/20 [==============================] - 1s 35ms/step - loss: 0.5922 - accuracy: 0.6585 - val_loss: 0.7408 - val_accuracy: 0.5430
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5902 - accuracy: 0.6635 - val_loss: 0.7535 - val_accuracy: 0.5460
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5894 - accuracy: 0.6620 - val_loss: 0.7457 - val_accuracy: 0.5571
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5858 - accuracy: 0.6694 - val_loss: 0.7585 - val_accuracy: 0.5511
# 20/20 [==============================] - 1s 35ms/step - loss: 0.5856 - accuracy: 0.6638 - val_loss: 0.7625 - val_accuracy: 0.5683
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5732 - accuracy: 0.6775 - val_loss: 0.7812 - val_accuracy: 0.5521
# 20/20 [==============================] - 1s 35ms/step - loss: 0.
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4856 - accuracy: 0.7316 - val_loss: 0.9958 - val_accuracy: 0.5794
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4789 - accuracy: 0.7389 - val_loss: 0.9530 - val_accuracy: 0.5743
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4847 - accuracy: 0.7344 - val_loss: 0.9649 - val_accuracy: 0.5814
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4803 - accuracy: 0.7349 - val_loss: 0.9304 - val_accuracy: 0.5935
# 20/20 [==============================] - 1s 45ms/step - loss: 0.4633 - accuracy: 0.7458 - val_loss: 0.9571 - val_accuracy: 0.5774
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4510 - accuracy: 0.7579 - val_loss: 0.9918 - val_accuracy: 0.5865
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4522 - accuracy: 0.7604 - val_loss: 1.0543 - val_accuracy: 0.5915
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4416 - accuracy: 0.7637 - val_loss: 1.1075 - val_accuracy: 0.6036
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4341 - accuracy: 0.7726 - val_loss: 1.1261 - val_accuracy: 0.5925
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4366 - accuracy: 0.7673 - val_loss: 1.1701 - val_accuracy: 0.5895
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4470 - accuracy: 0.7582 - val_loss: 1.1583 - val_accuracy: 0.5966
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4490 - accuracy: 0.7571 - val_loss: 1.1355 - val_accuracy: 0.5844
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4528 - accuracy: 0.7577 - val_loss: 1.0753 - val_accuracy: 0.5733
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4504 - accuracy: 0.7521 - val_loss: 1.0857 - val_accuracy: 0.5683
# 20/20 [==============================] - 1s 38ms/step - loss: 0.4657 - accuracy: 0.7455 - val_loss: 1.1489 - val_accuracy: 0.5713
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4722 - accuracy: 0.7465 - val_loss: 1.1453 - val_accuracy: 0.5794
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4590 - accuracy: 0.7478 - val_loss: 1.0727 - val_accuracy: 0.5713
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4585 - accuracy: 0.7564 - val_loss: 0.9622 - val_accuracy: 0.5935
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4547 - accuracy: 0.7546 - val_loss: 0.9426 - val_accuracy: 0.5935
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4427 - accuracy: 0.7604 - val_loss: 0.9819 - val_accuracy: 0.5774
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4310 - accuracy: 0.7751 - val_loss: 1.0316 - val_accuracy: 0.5895
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4314 - accuracy: 0.7713 - val_loss: 1.0167 - val_accuracy: 0.5915
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4251 - accuracy: 0.7764 - val_loss: 1.0136 - val_accuracy: 0.6036
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4202 - accuracy: 0.7693 - val_loss: 0.9953 - val_accuracy: 0.5935
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4101 - accuracy: 0.7817 - val_loss: 1.1038 - val_accuracy: 0.6006
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3964 - accuracy: 0.7860 - val_loss: 1.1203 - val_accuracy: 0.5945
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3915 - accuracy: 0.7905 - val_loss: 1.1627 - val_accuracy: 0.6067
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3874 - accuracy: 0.7984 - val_loss: 1.2046 - val_accuracy: 0.5976
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3923 - accuracy: 0.7936 - val_loss: 1.2316 - val_accuracy: 0.6026
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3925 - accuracy: 0.7893 - val_loss: 1.2023 - val_accuracy: 0.6087
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3867 - accuracy: 0.7976 - val_loss: 1.1865 - val_accuracy: 0.5905

# %%
y_predict = np.round(model.predict(X_test_norm))
y_predict = np.array([i[0] for i in y_predict.tolist()])
sum(y_predict == y_test)/len(y_test)
# Out:
# 0.6213592233009708
