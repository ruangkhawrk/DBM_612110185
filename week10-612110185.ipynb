4_0.jpg
# /kaggle/input/bdm-2021-face/612110165_2_0.jpg
# /kaggle/input/bdm-2021-face/622110240_2_0.jpg
# /kaggle/input/bdm-2021-face/612110159_1_0.jpg
# /kaggle/input/bdm-2021-face/622110172_2_0.jpg
# /kaggle/input/bdm-2021-face/622110206_2_0.jpg
# /kaggle/input/bdm-2021-face/612110174_2_0.jpg
# /kaggle/input/bdm-2021-face/622110209_2_1.jpg

# %%
import glob
filename = glob.glob("/kaggle/input/bdm-2021-face/*.*")
filename[0].split("_")
# Out:
# ['/kaggle/input/bdm-2021-face/622110140', '4', '0.jpg']

# %%
label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])

# %%
# !mkdir train

# %%
# !mkdir train/male
# !mkdir train/female

# %%
#!rm -rf train/female/*  #Delete Data

# %%
import shutil 
for i in range(len(label)):
    if label[i] == 0:
        shutil.copy(filename[i], '/kaggle/working/train/male/')
    else:
        shutil.copy(filename[i], '/kaggle/working/train/female/')

# %%
# !mkdir test
# !mkdir test/male
# !mkdir test/female

# %%
import glob
filemale = glob.glob("./train/male/*.*")
filefemale = glob.glob("./train/female/*.*")

# %%
midx = np.random.randint(len(filemale), size = 4)
fidx = np.random.randint(len(filefemale), size = 2)

# %%
for i in fidx:
    shutil.move(filefemale[i],'./test/female/')
for i in midx:
    shutil.move(filemale[i],'./test/male/')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        #rescale = 1.0/255.0,   # Intensity Normalized
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        validation_split=0.2)

# %%
train_dir = './train'
batchtrain = 15
batchval = 15
img_height = 100 
img_width  = 100
train_generator = data_generator.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batchtrain,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = data_generator.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batchval,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# Found 63 images belonging to 2 classes.
# Found 15 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'female': 0, 'male': 1}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
# preparing the layers in the Convolutional Deep Neural Network
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph() # Clear Model
    model = Sequential()
    model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', input_shape = train_generator.image_shape))
    model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation = 'relu'))
    model.add(Conv2D(filters = 8, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Flatten())
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 32, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 16, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 8, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = create_model()
fitted_model = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batchtrain,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batchval,
    epochs = 100)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021-09-20 16:08:15.553575: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-20 16:08:15.558794: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2299995000 Hz
# Epoch 1/100
# 4/4 [==============================] - 7s 2s/step - loss: 5.0426 - accuracy: 0.6389 - val_loss: 0.8673 - val_accuracy: 0.4000
# Epoch 2/100
# 4/4 [==============================] - 6s 2s/step - loss: 0.7249 - accuracy: 0.6844 - val_loss: 0.6237 - val_accuracy: 0.8667
# Epoch 3/100
# 4/4 [==============================] - 7s 1s/step - loss: 0.5714 - accuracy: 0.7244 - val_loss: 0.5916 - val_accuracy: 0.8000
# Epoch 4/100
# 4/4 [==============================] - 4s 1s/step - loss: 0.8549 - accuracy: 0.6376 - val_loss: 0.6760 - val_accuracy: 0.6667
# Epoch 5/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.5381 - accuracy: 0.8467 - val_loss: 0.6516 - val_accuracy: 0.5333
# Epoch 6/100
# 4/4 [==============================] - 4s 986ms/step - loss: 0.5356 - accuracy: 0.8070 - val_loss: 0.9421 - val_accuracy: 0.5333
# Epoch 7/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.5121 - accuracy: 0.7991 - val_loss: 0.5945 - val_accuracy: 0.6000
# Epoch 8/100
# 4/4 [==============================] - 5s 2s/step - loss: 0.4670 - accuracy: 0.7460 - val_loss: 0.6012 - val_accuracy: 0.6667
# Epoch 9/100
# 4/4 [==============================] - 4s 1s/step - loss: 0.4900 - accuracy: 0.7432 - val_loss: 0.4994 - val_accuracy: 0.8000
# Epoch 10/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.3966 - accuracy: 0.8572 - val_loss: 0.6580 - val_accuracy: 0.6667
# Epoch 11/100
# 4/4 [==============================] - 5s 2s/step - loss: 0.4361 - accuracy: 0.8096 - val_loss: 0.3816 - val_accuracy: 0.7333
# Epoch 12/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.3698 - accuracy: 0.8053 - val_loss: 0.7314 - val_accuracy: 0.5333
# Epoch 13/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.3981 - accuracy: 0.7733 - val_loss: 0.6522 - val_accuracy: 0.5333
# Epoch 14/100
# 4/4 [==============================] - 6s 2s/step - loss: 0.2918 - accuracy: 0.7911 - val_loss: 0.8101 - val_accuracy: 0.4000
# Epoch 15/100
# 4/4 [==============================] - 5s 2s/step - loss: 0
100
# 4/4 [==============================] - 5s 1s/step - loss: 0.1470 - accuracy: 0.9528 - val_loss: 0.2223 - val_accuracy: 0.8000
# Epoch 78/100
# 4/4 [==============================] - 5s 2s/step - loss: 0.1126 - accuracy: 0.9407 - val_loss: 0.2947 - val_accuracy: 0.8000
# Epoch 79/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.1622 - accuracy: 0.9089 - val_loss: 0.1544 - val_accuracy: 0.9333
# Epoch 80/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.0852 - accuracy: 0.9933 - val_loss: 0.2642 - val_accuracy: 0.9333
# Epoch 81/100
# 4/4 [==============================] - 6s 1s/step - loss: 0.0650 - accuracy: 0.9889 - val_loss: 0.3029 - val_accuracy: 0.8000
# Epoch 82/100
# 4/4 [==============================] - 4s 1s/step - loss: 0.0862 - accuracy: 0.9806 - val_loss: 0.6900 - val_accuracy: 0.7333
# Epoch 83/100
# 4/4 [==============================] - 5s 960ms/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.3711 - val_accuracy: 0.7333
# Epoch 84/100
# 4/4 [==============================] - 4s 887ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 1.0849 - val_accuracy: 0.7333
# Epoch 85/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.1584 - accuracy: 0.9279 - val_loss: 1.8746 - val_accuracy: 0.6000
# Epoch 86/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.0589 - accuracy: 0.9917 - val_loss: 0.2189 - val_accuracy: 0.8667
# Epoch 87/100
# 4/4 [==============================] - 4s 914ms/step - loss: 0.0350 - accuracy: 0.9706 - val_loss: 0.5947 - val_accuracy: 0.7333
# Epoch 88/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.0341 - accuracy: 0.9917 - val_loss: 1.0000 - val_accuracy: 0.6667
# Epoch 89/100
# 4/4 [==============================] - 5s 2s/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 1.5306 - val_accuracy: 0.6667
# Epoch 90/100
# 4/4 [==============================] - 5s 898ms/step - loss: 0.0530 - accuracy: 0.9917 - val_loss: 0.5979 - val_accuracy: 0.7333
# Epoch 91/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.0430 - accuracy: 0.9773 - val_loss: 0.2523 - val_accuracy: 0.9333
# Epoch 92/100
# 4/4 [==============================] - 6s 1s/step - loss: 0.2568 - accuracy: 0.9311 - val_loss: 0.1912 - val_accuracy: 0.8667
# Epoch 93/100
# 4/4 [==============================] - 4s 857ms/step - loss: 0.0697 - accuracy: 0.9806 - val_loss: 0.7009 - val_accuracy: 0.7333
# Epoch 94/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2610 - accuracy: 0.8668 - val_loss: 0.5727 - val_accuracy: 0.7333
# Epoch 95/100
# 4/4 [==============================] - 4s 1s/step - loss: 0.0828 - accuracy: 0.9678 - val_loss: 1.6414 - val_accuracy: 0.8000
# Epoch 96/100
# 4/4 [==============================] - 5s 2s/step - loss: 0.3035 - accuracy: 0.8596 - val_loss: 0.4807 - val_accuracy: 0.7333
# Epoch 97/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2034 - accuracy: 0.9357 - val_loss: 0.4663 - val_accuracy: 0.7333
# Epoch 98/100
# 4/4 [==============================] - 4s 1s/step - loss: 0.1900 - accuracy: 0.9018 - val_loss: 0.9808 - val_accuracy: 0.4000
# Epoch 99/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.1353 - accuracy: 0.9179 - val_loss: 0.4816 - val_accuracy: 0.6667
# Epoch 100/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2532 - accuracy: 0.9362 - val_loss: 0.5896 - val_accuracy: 0.6000

# %%
import matplotlib.pyplot as plt
# plotting accuracy and validation accuracy
accuracy = fitted_model.history['accuracy']
val_accuracy = fitted_model.history['val_accuracy']
plt.plot(range(len(accuracy)), accuracy, 'b-', label = 'accuracy')
plt.plot(range(len(val_accuracy)), val_accuracy, 'r-', label = 'val_accuracy')
plt.legend()

# %%
import glob
filefemale = glob.glob("./test/female/*.*")
filemale = glob.glob("./test/male/*.*")

# %%
from tensorflow.keras.preprocessing import image
# testing the model
plabel = []
for filename in filefemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==0)/len(plabel)
# Out:
# 1.0

# %%
plabel = []
for filename in filemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==1)/len(plabel)
# Out:
# 1.0
